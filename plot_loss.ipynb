# %%
# plot results manually
import matplotlib.pyplot as plt

# %%
val_loss = [
    0.814074,
0.693956,
0.704873,
0.699225,
0.694540,
0.693077,
0.694208,
0.695245,
0.695531,
0.696080,
0.695646,
0.695402,
0.694788,
0.694240,
0.693894,
0.693741,
0.693718,
0.693462,
0.693289,
0.693186,
0.693139,
0.693120,
0.693118,
0.693121,
0.693118,
0.693110,
0.693117,
0.693128,
0.693150,
]

# %%
tr_loss = [
0.693438,
0.800008,
0.693154,
0.701249,
0.698575,
0.697714,
0.693870,
0.694871,
0.695112,
 0.690192,
 0.695812,
 0.691097,
 0.695135,
 0.693016,
 0.691412,
 0.691924,
 0.692030,
 0.695841,
 0.693104,
 0.692948,
 0.692634,
 0.693301,
 0.693316,
 0.693785,
 0.693268,
 0.692816,
 0.693817,
 0.693740,
 0.693119,
 0.692807,

]

# %%
# Plot accuracy and loss
fig, ax = plt.subplots(1, 2, figsize=(15,5))
ax[0].plot(val_loss, label='Validation loss')
ax[0].plot(tr_loss, label='Training loss')
ax[0].set_title('LSTM Binary Cross Entropy Losses')
ax[0].set_xlabel('Batch')
ax[0].set_ylabel('Loss')
ax[0].legend()
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
